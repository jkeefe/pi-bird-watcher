# %% [markdown]
# # Custom image detection with fast.ai

# %% [markdown]
# ## Overview
#
# We want to make a model that will work for our specific, unique problem: detecting whether helicopter flight maps show a copter was "circling" or "not circling."
#
# ### Transfer learning with a pre-trained model
#
# One way to solve this problem would be to teach, or _train_ a _model_ – really a complex mathematical formula – to match images to labels. For good results, we'd need to use millions of images. It's doable ... but there's another option.
#
# We'll use a _pre-trained model_ – one already trained by some other, kind people, who built it using millions of images and then shared it on the internet for others to use. We'll use the "smarts" of that model, which has learned to detect patterns in images generally, to solve our particular problem. We do that by _additionally_ training the original model on our own data set – the helicopter flight maps.
#
# ### ResNet
#
# [ResNet](https://arxiv.org/abs/1512.03385) is a pre-trained model that was trained on the images and labels of 1.2 million pictures in a database called [ImageNet](http://www.image-net.org/about-overview).
#
# It is a _neural network_ that has "learned" how to "look" at those images and make a guess of what the image contains from a list of 1,000 possible labels.
#
# But we want just two labels: "circling" and "not circling"
#
# So we strip off the last calculations of the ResNet model ... the part that guesses between 1,000 possibilites ... and train it with our images to guess just two possibilities.
#
# ### fast.ai
#
# [Fast.ai](https://fast.ai) is the software we'll use to take the complex mathematical formula described by the ResNet model, do transfer-learning on the original model with our custom maps, and apply the final model to new images.
#
# ## The Plan
#
# We're going to train a model to recognize helicopter flight maps as either "circling" or "not circling" using a relatively small number of training images (just shy of 300 total).
#
# - We'll start with a moodel pre-trained on 1.2 million image.
# - Next we'll use "transfer learning" with fast.ai to further train that model with our helicopter maps

# %% [markdown]
# ## Credits
#
# This notebook started as a copy of the lesson 1 notebook in [Practical Deep Learning for Coders](https://course.fast.ai/), taught online by Jeremy Howard. I **highly** recommend this free online course.
#
# For more of my process here, see [this blog post](https://qz.ai/spotting-circling-helicopters/).
#
# -- John Keefe, [Quartz](https://qz.com), October 2019

# %% [markdown]
# ## Setup

# %% [markdown]
# ### For those using Google Colaboratory ...
#
# Be aware that Google Colab instances are ephemeral -- they vanish *Poof* when you close them, or after a period of sitting idle (currently 90 minutes), or if you use one for more than 12 hours.
#
# If you're using Google Colaboratory, be sure to set your runtime to "GPU" which speeds up your notebook for machine learning:
#
# ![change runtime](https://qz-aistudio-public.s3.amazonaws.com/workshops/notebook_images/change_runtime_2.jpg)
# ![pick gpu](https://qz-aistudio-public.s3.amazonaws.com/workshops/notebook_images/pick_gpu_2.jpg)
#
# Then run this cell:

# %%
## ALL GOOGLE COLAB USERS RUN THIS CELL

## This runs a script that installs fast.ai
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %% [markdown]
# ### For those _not_ using Google Colaboratory ...
#
# This section is just for people who decide to use one of the notebooks on a system other than Google Colaboartory.
#
# Those people should run the cell below.

# %%
## NON-COLABORATORY USERS SHOULD RUN THIS CELL
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### Everybody do this ...

# %% [markdown]
# Everyone needs to run the next cell, which initializes the Python libraries we'll use in this notebook.

# %%
## AND *EVERYBODY* SHOULD RUN THIS CELL
import warnings
warnings.filterwarnings('ignore')
from fastai.vision import *
from fastai.metrics import error_rate
import fastai
print(f'fastai: {fastai.__version__}')
print(f'cuda: {torch.cuda.is_available()}')
# Out:
# fastai: 1.0.61
# cuda: True

# %% [markdown]
# ## The Data

# %% [markdown]
# Downloading bird image data from [Caltech-UCSD Birds-200-2011](http://www.vision.caltech.edu/visipedia/CUB-200-2011.html), which is based on this paper:
#
# Wah C., Branson S., Welinder P., Perona P., Belongie S. “The Caltech-UCSD Birds-200-2011 Dataset.” Computation & Neural Systems Technical Report, CNS-TR-2011-001. [download pdf](http://www.vision.caltech.edu/visipedia/papers/CUB_200_2011.pdf)

# %%
# Run this cell to download the data we'll use for this exercise
# !wget -N http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz --quiet
# !tar zxvf CUB_200_2011.tgz > /dev/null

# %%
# %ls
# Out:
# attributes.txt  CUB_200_2011/  CUB_200_2011.tgz  data@  models@

# %%
# !head CUB_200_2011/images.txt
# Out:
# 1 001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg
# 2 001.Black_footed_Albatross/Black_Footed_Albatross_0009_34.jpg
# 3 001.Black_footed_Albatross/Black_Footed_Albatross_0002_55.jpg
# 4 001.Black_footed_Albatross/Black_Footed_Albatross_0074_59.jpg
# 5 001.Black_footed_Albatross/Black_Footed_Albatross_0014_89.jpg
# 6 001.Black_footed_Albatross/Black_Footed_Albatross_0085_92.jpg
# 7 001.Black_footed_Albatross/Black_Footed_Albatross_0031_100.jpg
# 8 001.Black_footed_Albatross/Black_Footed_Albatross_0051_796103.jpg
# 9 001.Black_footed_Albatross/Black_Footed_Albatross_0010_796097.jpg
# 10 001.Black_footed_Albatross/Black_Footed_Albatross_0025_796057.jpg

# %%
# %ls CUB_200_2011
# Out:
# attributes/         image_class_labels.txt  parts/
# bounding_boxes.txt  images/                 README
# classes.txt         images.txt              train_test_split.txt

# %%
from IPython.display import Image as Show

# %%
Show(filename='CUB_200_2011/images/199.Winter_Wren/Winter_Wren_0142_190379.jpg')

# %% [markdown]
# ## Using dataframe instead of detecting from files
#
# The faster way to bring in the data would be to use fast.ai's functions for extracting labels from the file name and just go. In that case, I'd probably just split the training & validation sets randomly.
#
# But the data set includes a train-valid-split file, which appears to ensure there are at least *some* versions of each bird in each set. (A random selection could miss some birds.)
#
# In order to make sure those line up, I'm pulling everything into a Pandas dataframe. It also helps me keep track of everything :-)

# %%
import pandas as pd
pd.set_option('max_colwidth', -1)  # so I can see the whole image names in this notebook

# %%
data_path ='./CUB_200_2011/images'

# %%
images_list = pd.read_csv("CUB_200_2011/images.txt", sep=" ", header=None, names=["id", "name"])

# %%
images_list.head()
# Out:
#    id                                                           name
# 0  1   001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg
# 1  2   001.Black_footed_Albatross/Black_Footed_Albatross_0009_34.jpg
# 2  3   001.Black_footed_Albatross/Black_Footed_Albatross_0002_55.jpg
# 3  4   001.Black_footed_Albatross/Black_Footed_Albatross_0074_59.jpg
# 4  5   001.Black_footed_Albatross/Black_Footed_Albatross_0014_89.jpg

# %%
images_list['label']=images_list['name'].str.extract(r'\/([A-Z|a-z|_]+)_\d')
images_list['label']=images_list['label'].str.replace('_', ' ')

# %%
images_list.head()
# Out:
#    id  ...                   label
# 0  1   ...  Black Footed Albatross
# 1  2   ...  Black Footed Albatross
# 2  3   ...  Black Footed Albatross
# 3  4   ...  Black Footed Albatross
# 4  5   ...  Black Footed Albatross
#
# [5 rows x 3 columns]

# %%
train_test_list = pd.read_csv("CUB_200_2011/train_test_split.txt", sep=" ", header=None, names=["id", "split"])

# %%
train_test_list.head()
# Out:
#    id  split
# 0  1   0
# 1  2   1
# 2  3   0
# 3  4   1
# 4  5   1

# %%
train_test_list['is_valid'] = (train_test_list['split'] == 1 )

# %%
train_test_list.head()
# Out:
#    id  split  is_valid
# 0  1   0      False
# 1  2   1      True
# 2  3   0      False
# 3  4   1      True
# 4  5   1      True

# %%
train_test_list.drop(columns="split", inplace=True)

# %%
images_df = pd.merge(images_list, train_test_list, on="id")

# %%
images_df.head()
# Out:
#    id  ... is_valid
# 0  1   ...  False
# 1  2   ...  True
# 2  3   ...  False
# 3  4   ...  True
# 4  5   ...  True
#
# [5 rows x 4 columns]

# %%
my_transforms = get_transforms() # get_transforms() is the default transform set

data = (ImageList.from_df(images_df, data_path, cols='name') #Where to find the data?
        .split_from_df(col='is_valid') #How to split in train/valid?
        .label_from_df(cols='label') #How to label? -> depending on the folder of the filenames
        .transform(my_transforms, size=(224,224)) #Data transforms applied, size of images shrink to 224
        .databunch(bs=48))

# %%
data.show_batch(rows=3)

# %%
print(data.classes)
# Out:
# ['Acadian Flycatcher', 'American Crow', 'American Goldfinch', 'American Pipit', 'American Redstart', 'American Three Toed Woodpecker', 'Anna Hummingbird', 'Artic Tern', 'Baird Sparrow', 'Baltimore Oriole', 'Bank Swallow', 'Barn Swallow', 'Bay Breasted Warbler', 'Belted Kingfisher', 'Bewick Wren', 'Black And White Warbler', 'Black Billed Cuckoo', 'Black Capped Vireo', 'Black Footed Albatross', 'Black Tern', 'Black Throated Blue Warbler', 'Black Throated Sparrow', 'Blue Grosbeak', 'Blue Headed Vireo', 'Blue Jay', 'Blue Winged Warbler', 'Boat Tailed Grackle', 'Bobolink', 'Bohemian Waxwing', 'Brandt Cormorant', 'Brewer Blackbird', 'Brewer Sparrow', 'Bronzed Cowbird', 'Brown Creeper', 'Brown Pelican', 'Brown Thrasher', 'Cactus Wren', 'California Gull', 'Canada Warbler', 'Cape Glossy Starling', 'Cape May Warbler', 'Cardinal', 'Carolina Wren', 'Caspian Tern', 'Cedar Waxwing', 'Cerulean Warbler', 'Chestnut Sided Warbler', 'Chipping Sparrow', 'Chuck Will Widow', 'Clark Nutcracker', 'Clay Colored Sparrow', 'Cliff Swallow', 'Common Raven', 'Common Tern', 'Common Yellowthroat', 'Crested Auklet', 'Dark Eyed Junco', 'Downy Woodpecker', 'Eared Grebe', 'Eastern Towhee', 'Elegant Tern', 'European Goldfinch', 'Evening Grosbeak', 'Field Sparrow', 'Fish Crow', 'Florida Jay', 'Forsters Tern', 'Fox Sparrow', 'Frigatebird', 'Gadwall', 'Geococcyx', 'Glaucous Winged Gull', 'Golden Winged Warbler', 'Grasshopper Sparrow', 'Gray Catbird', 'Gray Crowned Rosy Finch', 'Gray Kingbird', 'Great Crested Flycatcher', 'Great Grey Shrike', 'Green Jay', 'Green Kingfisher', 'Green Tailed Towhee', 'Green Violetear', 'Groove Billed Ani', 'Harris Sparrow', 'Heermann Gull', 'Henslow Sparrow', 'Herring Gull', 'Hooded Merganser', 'Hooded Oriole', 'Hooded Warbler', 'Horned Grebe', 'Horned Lark', 'Horned Puffin', 'House Sparrow', 'House Wren', 'Indigo Bunting', 'Ivory Gull', 'Kentucky Warbler', 'Laysan Albatross', 'Lazuli Bunting', 'Le Conte Sparrow', 'Least Auklet', 'Least Flycatcher', 'Least Tern', 'Lincoln Sparrow', 'Loggerhead Shrike', 'Long Tailed Jaeger', 'Louisiana Waterthrush', 'Magnolia Warbler', 'Mallard', 'Mangrove Cuckoo', 'Marsh Wren', 'Mockingbird', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Nelson Sharp Tailed Sparrow', 'Nighthawk', 'Northern Flicker', 'Northern Fulmar', 'Northern Waterthrush', 'Olive Sided Flycatcher', 'Orange Crowned Warbler', 'Orchard Oriole', 'Ovenbird', 'Pacific Loon', 'Painted Bunting', 'Palm Warbler', 'Parakeet Auklet', 'Pelagic Cormorant', 'Philadelphia Vireo', 'Pied Billed Grebe', 'Pied Kingfisher', 'Pigeon Guillemot', 'Pileated Woodpecker', 'Pine Grosbeak', 'Pine Warbler', 'Pomarine Jaeger', 'Prairie Warbler', 'Prothonotary Warbler', 'Purple Finch', 'Red Bellied Woodpecker', 'Red Breasted Merganser', 'Red Cockaded Woodpecker', 'Red Eyed Vireo', 'Red Faced Cormorant', 'Red Headed Woodpecker', 'Red Legged Kittiwake', 'Red Winged Blackbird', 'Rhinoceros Auklet', 'Ring Billed Gull', 'Ringed Kingfisher', 'Rock Wren', 'Rose Breasted Grosbeak', 'Ruby Throated Hummingbird', 'Rufous Hummingbird', 'Rusty Blackbird', 'Sage Thrasher', 'Savannah Sparrow', 'Sayornis', 'Scarlet Tanager', 'Scissor Tailed Flycatcher', 'Scott Oriole', 'Seaside Sparrow', 'Shiny Cowbird', 'Slaty Backed Gull', 'Song Sparrow', 'Sooty Albatross', 'Spotted Catbird', 'Summer Tanager', 'Swainson Warbler', 'Tennessee Warbler', 'Tree Sparrow', 'Tree Swallow', 'Tropical Kingbird', 'Vermilion Flycatcher', 'Vesper Sparrow', 'Warbling Vireo', 'Western Grebe', 'Western Gull', 'Western Meadowlark', 'Western Wood Pewee', 'Whip Poor Will', 'White Breasted Kingfisher', 'White Breasted Nuthatch', 'White Crowned Sparrow', 'White Eyed Vireo', 'White Necked Raven', 'White Pelican', 'White Throated Sparrow', 'Wilson Warbler', 'Winter Wren', 'Worm Eating Warbler', 'Yellow Bellied Flycatcher', 'Yellow Billed Cuckoo', 'Yellow Breasted Chat', 'Yellow Headed Blackbird', 'Yellow Throated Vireo', 'Yellow Warbler']

# %% [markdown]
# ## The Code

# %% [markdown]
# Now we will start training our model - which is a convolutional neural network(!) For a deep dive on that, definitely check out the fast.ai courses.
#
# ### Transfer learning with resnet34
#
# Training a computer-vision mode from scratch to solve our problem would take thousands of images. Maybe more. Instead we take advantage of an existing model that was trained to detect objects -- from planes, to cars, to dogs, to birds -- by processing millions of images. This model is called "resnet34."
#
# With fast.ai we can infuse this model with our images (and their labels). This takes advantage of all of resnet34's "knowledge" of image-detection and tacks on our particular problem. This technique is called "transfer learning."
#
# First we load our `data` and `model.resnet34` together into a training model known as a "learner."

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(IntProgress(value=0, max=102502400), HTML(value='')))

# %% [markdown]
# We will train for 6 epochs (6 cycles through all our data).

# %%
learn.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.694536</td>
#       <td>2.680858</td>
#       <td>0.637971</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.760970</td>
#       <td>1.982280</td>
#       <td>0.508509</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.954493</td>
#       <td>1.628027</td>
#       <td>0.427261</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.461992</td>
#       <td>1.427832</td>
#       <td>0.383884</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.103289</td>
#       <td>1.295313</td>
#       <td>0.344511</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.826898</td>
#       <td>1.222003</td>
#       <td>0.325159</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.604860</td>
#       <td>1.180966</td>
#       <td>0.315816</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.505451</td>
#       <td>1.166928</td>
#       <td>0.313814</td>
#       <td>02:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='77' class='' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       64.17% [77/120 00:43<00:24 1.7173]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-3))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='79' class='' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       65.83% [79/120 00:47<00:24 0.6167]
#     </div>

# %% [markdown]
# ### How are we doing?

# %% [markdown]
# So far, we have a pretty good error rate.
#
# Let's look to see where the model was most confused, and whether what the model predicted was reasonable or not.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# You can add "heatmap=True" to the `interp` line above, like this:
#
# ```
# interp.plot_top_losses(9, heatmap=True)
# ```
#
# The "hot" areas of the images are the parts the model is using to make its decision.
#
# In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see how the mistakes are being made.

# %%
interp.plot_confusion_matrix(figsize=(100,100), dpi=60)

# %%
interp.most_confused(min_val=5)
# Out:
# [('Whip Poor Will', 'Chuck Will Widow', 13),
#  ('Common Tern', 'Forsters Tern', 12),
#  ('Caspian Tern', 'Elegant Tern', 11),
#  ('Blue Grosbeak', 'Indigo Bunting', 10),
#  ('Elegant Tern', 'Caspian Tern', 10),
#  ('Nelson Sharp Tailed Sparrow', 'Le Conte Sparrow', 10),
#  ('Brandt Cormorant', 'Pelagic Cormorant', 9),
#  ('Pomarine Jaeger', 'Long Tailed Jaeger', 9),
#  ('Chuck Will Widow', 'Whip Poor Will', 8),
#  ('Clay Colored Sparrow', 'Brewer Sparrow', 8),
#  ('Cliff Swallow', 'Barn Swallow', 8),
#  ('Great Grey Shrike', 'Loggerhead Shrike', 8),
#  ('Northern Waterthrush', 'Louisiana Waterthrush', 8),
#  ('Olive Sided Flycatcher', 'Western Wood Pewee', 8),
#  ('Yellow Bellied Flycatcher', 'Acadian Flycatcher', 8),
#  ('Fish Crow', 'Common Raven', 7),
#  ('Shiny Cowbird', 'Brewer Blackbird', 7),
#  ('American Crow', 'Common Raven', 6),
#  ('Black Capped Vireo', 'Black Throated Sparrow', 6),
#  ('California Gull', 'Western Gull', 6),
#  ('Common Raven', 'American Crow', 6),
#  ('Common Tern', 'Caspian Tern', 6),
#  ('Fox Sparrow', 'Song Sparrow', 6),
#  ('Herring Gull', 'California Gull', 6),
#  ('Herring Gull', 'Western Gull', 6),
#  ('Least Flycatcher', 'Acadian Flycatcher', 6),
#  ('Ringed Kingfisher', 'Belted Kingfisher', 6),
#  ('Ruby Throated Hummingbird', 'Rufous Hummingbird', 6),
#  ('American Crow', 'Fish Crow', 5),
#  ('Anna Hummingbird', 'Ruby Throated Hummingbird', 5),
#  ('Artic Tern', 'Common Tern', 5),
#  ('Brewer Blackbird', 'Shiny Cowbird', 5),
#  ('California Gull', 'Glaucous Winged Gull', 5),
#  ('Common Raven', 'Fish Crow', 5),
#  ('Herring Gull', 'Glaucous Winged Gull', 5),
#  ('Horned Grebe', 'Eared Grebe', 5),
#  ('Least Tern', 'Forsters Tern', 5),
#  ('Long Tailed Jaeger', 'Pomarine Jaeger', 5),
#  ('Nashville Warbler', 'Orange Crowned Warbler', 5),
#  ('Northern Fulmar', 'Pomarine Jaeger', 5),
#  ('Orange Crowned Warbler', 'Tennessee Warbler', 5),
#  ('Red Eyed Vireo', 'Black Billed Cuckoo', 5),
#  ('Savannah Sparrow', 'Vesper Sparrow', 5),
#  ('Scarlet Tanager', 'Vermilion Flycatcher', 5),
#  ('Slaty Backed Gull', 'Western Gull', 5),
#  ('Song Sparrow', 'Lincoln Sparrow', 5),
#  ('Warbling Vireo', 'Philadelphia Vireo', 5),
#  ('Winter Wren', 'House Wren', 5),
#  ('Yellow Bellied Flycatcher', 'Great Crested Flycatcher', 5),
#  ('Yellow Throated Vireo', 'Pine Warbler', 5),
#  ('Acadian Flycatcher', 'Western Wood Pewee', 4),
#  ('American Three Toed Woodpecker', 'Red Cockaded Woodpecker', 4),
#  ('Artic Tern', 'Forsters Tern', 4),
#  ('Baird Sparrow', 'Grasshopper Sparrow', 4),
#  ('Baird Sparrow', 'Henslow Sparrow', 4),
#  ('Baird Sparrow', 'Savannah Sparrow', 4),
#  ('Baltimore Oriole', 'Orchard Oriole', 4),
#  ('Bewick Wren', 'House Wren', 4),
#  ('Boat Tailed Grackle', 'Shiny Cowbird', 4),
#  ('Common Tern', 'Artic Tern', 4),
#  ('Crested Auklet', 'Parakeet Auklet', 4),
#  ('Eared Grebe', 'Horned Grebe', 4),
#  ('Eared Grebe', 'Western Grebe', 4),
#  ('Henslow Sparrow', 'Le Conte Sparrow', 4),
#  ('Hooded Warbler', 'Kentucky Warbler', 4),
#  ('Loggerhead Shrike', 'Great Grey Shrike', 4),
#  ('Mourning Warbler', 'Nashville Warbler', 4),
#  ('Ring Billed Gull', 'Glaucous Winged Gull', 4),
#  ('Rufous Hummingbird', 'Ruby Throated Hummingbird', 4),
#  ('Rusty Blackbird', 'Brewer Blackbird', 4),
#  ('Savannah Sparrow', 'Song Sparrow', 4),
#  ('Slaty Backed Gull', 'California Gull', 4),
#  ('Slaty Backed Gull', 'Herring Gull', 4),
#  ('Sooty Albatross', 'Black Footed Albatross', 4),
#  ('Swainson Warbler', 'Red Eyed Vireo', 4),
#  ('Tennessee Warbler', 'Orange Crowned Warbler', 4),
#  ('Tree Sparrow', 'Chipping Sparrow', 4),
#  ('Vesper Sparrow', 'Song Sparrow', 4),
#  ('Western Gull', 'California Gull', 4),
#  ('Western Wood Pewee', 'Least Flycatcher', 4),
#  ('Western Wood Pewee', 'Sayornis', 4),
#  ('Whip Poor Will', 'Nighthawk', 4),
#  ('American Redstart', 'Eastern Towhee', 3),
#  ('Artic Tern', 'Elegant Tern', 3),
#  ('Baird Sparrow', 'Le Conte Sparrow', 3),
#  ('Baird Sparrow', 'Vesper Sparrow', 3),
#  ('Bank Swallow', 'Tree Swallow', 3),
#  ('Barn Swallow', 'Cliff Swallow', 3),
#  ('Bay Breasted Warbler', 'Yellow Throated Vireo', 3),
#  ('Belted Kingfisher', 'Pied Kingfisher', 3),
#  ('Belted Kingfisher', 'Ringed Kingfisher', 3),
#  ('Black Billed Cuckoo', 'Yellow Billed Cuckoo', 3),
#  ('Black Capped Vireo', 'Blue Headed Vireo', 3),
#  ('Black Tern', 'Pomarine Jaeger', 3),
#  ('Black Throated Blue Warbler', 'Blue Headed Vireo', 3),
#  ('Black Throated Blue Warbler', 'Cerulean Warbler', 3),
#  ('Boat Tailed Grackle', 'Rusty Blackbird', 3),
#  ('Brewer Sparrow', 'Baird Sparrow', 3),
#  ('Brewer Sparrow', 'Vesper Sparrow', 3),
#  ('California Gull', 'Herring Gull', 3),
#  ('Carolina Wren', 'Marsh Wren', 3),
#  ('Cliff Swallow', 'Bank Swallow', 3),
#  ('Elegant Tern', 'Common Tern', 3),
#  ('Field Sparrow', 'Song Sparrow', 3),
#  ('Fish Crow', 'American Crow', 3),
#  ('Fish Crow', 'Shiny Cowbird', 3),
#  ('Forsters Tern', 'Elegant Tern', 3),
#  ('Glaucous Winged Gull', 'California Gull', 3),
#  ('Grasshopper Sparrow', 'Vesper Sparrow', 3),
#  ('Henslow Sparrow', 'Lincoln Sparrow', 3),
#  ('Hooded Warbler', 'Wilson Warbler', 3),
#  ('Ivory Gull', 'Glaucous Winged Gull', 3),
#  ('Laysan Albatross', 'Pomarine Jaeger', 3),
#  ('Laysan Albatross', 'Sooty Albatross', 3),
#  ('Least Flycatcher', 'Sayornis', 3),
#  ('Least Flycatcher', 'Western Wood Pewee', 3),
#  ('Least Tern', 'Elegant Tern', 3),
#  ('Lincoln Sparrow', 'Northern Waterthrush', 3),
#  ('Long Tailed Jaeger', 'Least Tern', 3),
#  ('Long Tailed Jaeger', 'Sooty Albatross', 3),
#  ('Louisiana Waterthrush', 'Northern Waterthrush', 3),
#  ('Nashville Warbler', 'Mourning Warbler', 3),
#  ('Nelson Sharp Tailed Sparrow', 'Seaside Sparrow', 3),
#  ('Nighthawk', 'Chuck Will Widow', 3),
#  ('Nighthawk', 'Whip Poor Will', 3),
#  ('Orange Crowned Warbler', 'Nashville Warbler', 3),
#  ('Palm Warbler', 'Myrtle Warbler', 3),
#  ('Pelagic Cormorant', 'Brandt Cormorant', 3),
#  ('Pelagic Cormorant', 'Red Faced Cormorant', 3),
#  ('Philadelphia Vireo', 'Warbling Vireo', 3),
#  ('Pine Warbler', 'Yellow Throated Vireo', 3),
#  ('Pomarine Jaeger', 'Frigatebird', 3),
#  ('Red Bellied Woodpecker', 'Northern Flicker', 3),
#  ('Red Faced Cormorant', 'Pelagic Cormorant', 3),
#  ('Red Headed Woodpecker', 'Pileated Woodpecker', 3),
#  ('Ring Billed Gull', 'Herring Gull', 3),
#  ('Sayornis', 'Least Flycatcher', 3),
#  ('Sooty Albatross', 'Black Tern', 3),
#  ('Vermilion Flycatcher', 'Scarlet Tanager', 3),
#  ('Vesper Sparrow', 'Brewer Sparrow', 3),
#  ('White Necked Raven', 'Common Raven', 3),
#  ('White Pelican', 'Brown Pelican', 3),
#  ('White Throated Sparrow', 'White Crowned Sparrow', 3),
#  ('Worm Eating Warbler', 'Swainson Warbler', 3),
#  ('Yellow Billed Cuckoo', 'Black Billed Cuckoo', 3),
#  ('Yellow Breasted Chat', 'Nashville Warbler', 3),
#  ('Acadian Flycatcher', 'Cerulean Warbler', 2),
#  ('Acadian Flycatcher', 'Least Flycatcher', 2),
#  ('Acadian Flycatcher', 'Yellow Bellied Flycatcher', 2),
#  ('American Crow', 'Brewer Blackbird', 2),
#  ('American Crow', 'Rusty Blackbird', 2),
#  ('American Goldfinch', 'Evening Grosbeak', 2),
#  ('American Goldfinch', 'Yellow Throated Vireo', 2),
#  ('American Pipit', 'Sage Thrasher', 2),
#  ('American Three Toed Woodpecker', 'Brown Creeper', 2),
#  ('Bank Swallow', 'Black Throated Sparrow', 2),
#  ('Bank Swallow', 'Cliff Swallow', 2),
#  ('Belted Kingfisher', 'Green Kingfisher', 2),
#  ('Bewick Wren', 'Marsh Wren', 2),
#  ('Bewick Wren', 'Rock Wren', 2),
#  ('Black Billed Cuckoo', 'Mangrove Cuckoo', 2),
#  ('Black Billed Cuckoo', 'Red Eyed Vireo', 2),
#  ('Black Tern', 'Brandt Cormorant', 2),
#  ('Blue Headed Vireo', 'Cerulean Warbler', 2),
#  ('Blue Headed Vireo', 'Tennessee Warbler', 2),
#  ('Blue Jay', 'Florida Jay', 2),
#  ('Blue Jay', 'White Breasted Nuthatch', 2),
#  ('Blue Winged Warbler', 'Tennessee Warbler', 2),
#  ('Blue Winged Warbler', 'Wilson Warbler', 2),
#  ('Bohemian Waxwing', 'Cedar Waxwing', 2),
#  ('Brandt Cormorant', 'Black Footed Albatross', 2),
#  ('Brewer Blackbird', 'American Crow', 2),
#  ('Brewer Blackbird', 'Fish Crow', 2),
#  ('Brewer Blackbird', 'Gray Catbird', 2),
#  ('Brewer Sparrow', 'Bewick Wren', 2),
#  ('Brewer Sparrow', 'Clay Colored Sparrow', 2),
#  ('Brewer Sparrow', 'Sage Thrasher', 2),
#  ('Brown Thrasher', 'Savannah Sparrow', 2),
#  ('Cactus Wren', 'Geococcyx', 2),
#  ('Cactus Wren', 'Rock Wren', 2),
#  ('Canada Warbler', 'Magnolia Warbler', 2),
#  ('Canada Warbler', 'Mangrove Cuckoo', 2),
#  ('Cape May Warbler', 'Chestnut Sided Warbler', 2),
#  ('Cape May Warbler', 'Palm Warbler', 2),
#  ('Cape May Warbler', 'Prairie Warbler', 2),
#  ('Cape May Warbler', 'Western Meadowlark', 2),
#  ('Cardinal', 'Pine Grosbeak', 2),
#  ('Cardinal', 'Vermilion Flycatcher', 2),
#  ('Chestnut Sided Warbler', 'Yellow Billed Cuckoo', 2),
#  ('Chipping Sparrow', 'Clay Colored Sparrow', 2),
#  ('Chipping Sparrow', 'Field Sparrow', 2),
#  ('Chipping Sparrow', 'Marsh Wren', 2),
#  ('Chipping Sparrow', 'Tree Sparrow', 2),
#  ('Chipping Sparrow', 'Vesper Sparrow', 2),
#  ('Chuck Will Widow', 'Cactus Wren', 2),
#  ('Clay Colored Sparrow', 'Chipping Sparrow', 2),
#  ('Common Raven', 'White Necked Raven', 2),
#  ('Common Yellowthroat', 'Nashville Warbler', 2),
#  ('Common Yellowthroat', 'Yellow Breasted Chat', 2),
#  ('Crested Auklet', 'Red Faced Cormorant', 2),
#  ('Downy Woodpecker', 'Pied Kingfisher', 2),
#  ('Eastern Towhee', 'Bay Breasted Warbler', 2),
#  ('Eastern Towhee', 'Black Throated Blue Warbler', 2),
#  ('Eastern Towhee', 'Orchard Oriole', 2),
#  ('Field Sparrow', 'Chipping Sparrow', 2),
#  ('Field Sparrow', 'Clay Colored Sparrow', 2),
#  ('Fish Crow', 'White Necked Raven', 2),
#  ('Florida Jay', 'Gray Kingbird', 2),
#  ('Florida Jay', 'Mangrove Cuckoo', 2),
#  ('Forsters Tern', 'Artic Tern', 2),
#  ('Forsters Tern', 'Caspian Tern', 2),
#  ('Forsters Tern', 'Common Tern', 2),
#  ('Fox Sparrow', 'Sage Thrasher', 2),
#  ('Glaucous Winged Gull', 'Herring Gull', 2),
#  ('Grasshopper Sparrow', 'American Pipit', 2),
#  ('Grasshopper Sparrow', 'Clay Colored Sparrow', 2),
#  ('Gray Crowned Rosy Finch', 'American Pipit', 2),
#  ('Gray Kingbird', 'Sayornis', 2),
#  ('Great Crested Flycatcher', 'Tropical Kingbird', 2),
#  ('Green Kingfisher', 'Ringed Kingfisher', 2),
#  ('Green Tailed Towhee', 'Brewer Sparrow', 2),
#  ('Green Violetear', 'Rufous Hummingbird', 2),
#  ('Harris Sparrow', 'Lincoln Sparrow', 2),
#  ('Harris Sparrow', 'Tree Sparrow', 2),
#  ('Heermann Gull', 'Herring Gull', 2),
#  ('Henslow Sparrow', 'Clay Colored Sparrow', 2),
#  ('Herring Gull', 'Forsters Tern', 2),
#  ('Hooded Oriole', 'Prothonotary Warbler', 2),
#  ('House Sparrow', 'Brewer Sparrow', 2),
#  ('House Sparrow', 'Tree Sparrow', 2),
#  ('House Sparrow', 'White Crowned Sparrow', 2),
#  ('Kentucky Warbler', 'Common Yellowthroat', 2),
#  ('Laysan Albatross', 'Black Footed Albatross', 2),
#  ('Lazuli Bunting', 'Blue Grosbeak', 2),
#  ('Lazuli Bunting', 'Cerulean Warbler', 2),
#  ('Le Conte Sparrow', 'Henslow Sparrow', 2),
#  ('Le Conte Sparrow', 'Vesper Sparrow', 2),
#  ('Least Flycatcher', 'Blue Headed Vireo', 2),
#  ('Least Tern', 'Artic Tern', 2),
#  ('Least Tern', 'Caspian Tern', 2),
#  ('Lincoln Sparrow', 'Savannah Sparrow', 2),
#  ('Long Tailed Jaeger', 'Frigatebird', 2),
#  ('Long Tailed Jaeger', 'Laysan Albatross', 2),
#  ('Mallard', 'Gadwall', 2),
#  ('Mallard', 'Hooded Merganser', 2),
#  ('Mangrove Cuckoo', 'Warbling Vireo', 2),
#  ('Mangrove Cuckoo', 'Yellow Billed Cuckoo', 2),
#  ('Marsh Wren', 'Carolina Wren', 2),
#  ('Marsh Wren', 'House Wren', 2),
#  ('Nashville Warbler', 'Painted Bunting', 2),
#  ('Nighthawk', 'Pomarine Jaeger', 2),
#  ('Northern Flicker', 'Brown Thrasher', 2),
#  ('Northern Fulmar', 'Black Footed Albatross', 2),
#  ('Northern Fulmar', 'Sooty Albatross', 2),
#  ('Northern Waterthrush', 'American Pipit', 2),
#  ('Northern Waterthrush', 'Worm Eating Warbler', 2),
#  ('Olive Sided Flycatcher', 'Sayornis', 2),
#  ('Orange Crowned Warbler', 'Warbling Vireo', 2),
#  ('Orange Crowned Warbler', 'Wilson Warbler', 2),
#  ('Ovenbird', 'Field Sparrow', 2),
#  ('Painted Bunting', 'Vermilion Flycatcher', 2),
#  ('Palm Warbler', 'Great Crested Flycatcher', 2),
#  ('Palm Warbler', 'Northern Waterthrush', 2),
#  ('Palm Warbler', 'Swainson Warbler', 2),
#  ('Pelagic Cormorant', 'Frigatebird', 2),
#  ('Pelagic Cormorant', 'Red Breasted Merganser', 2),
#  ('Pelagic Cormorant', 'Rhinoceros Auklet', 2),
#  ('Philadelphia Vireo', 'Mourning Warbler', 2),
#  ('Philadelphia Vireo', 'Yellow Bellied Flycatcher', 2),
#  ('Pied Billed Grebe', 'Horned Grebe', 2),
#  ('Pine Warbler', 'Prairie Warbler', 2),
#  ('Pine Warbler', 'Yellow Warbler', 2),
#  ('Pomarine Jaeger', 'Black Footed Albatross', 2),
#  ('Prairie Warbler', 'Cape May Warbler', 2),
#  ('Prairie Warbler', 'Magnolia Warbler', 2),
#  ('Prairie Warbler', 'Pine Warbler', 2),
#  ('Prothonotary Warbler', 'Yellow Headed Blackbird', 2),
#  ('Prothonotary Warbler', 'Yellow Warbler', 2),
#  ('Purple Finch', 'Vermilion Flycatcher', 2),
#  ('Red Breasted Merganser', 'Forsters Tern', 2),
#  ('Red Cockaded Woodpecker', 'Brown Creeper', 2),
#  ('Red Eyed Vireo', 'Great Crested Flycatcher', 2),
#  ('Red Eyed Vireo', 'Mangrove Cuckoo', 2),
#  ('Red Eyed Vireo', 'Warbling Vireo', 2),
#  ('Red Legged Kittiwake', 'Western Gull', 2),
#  ('Rhinoceros Auklet', 'Pigeon Guillemot', 2),
#  ('Ring Billed Gull', 'California Gull', 2),
#  ('Ring Billed Gull', 'Elegant Tern', 2),
#  ('Ring Billed Gull', 'Northern Fulmar', 2),
#  ('Ringed Kingfisher', 'Green Kingfisher', 2),
#  ('Ruby Throated Hummingbird', 'Anna Hummingbird', 2),
#  ('Rufous Hummingbird', 'Anna Hummingbird', 2),
#  ('Rusty Blackbird', 'Yellow Billed Cuckoo', 2),
#  ('Sage Thrasher', 'Cactus Wren', 2),
#  ('Savannah Sparrow', 'Nelson Sharp Tailed Sparrow', 2),
#  ('Sayornis', 'Scissor Tailed Flycatcher', 2),
#  ('Scarlet Tanager', 'Summer Tanager', 2),
#  ('Scott Oriole', 'Hooded Oriole', 2),
#  ('Scott Oriole', 'Myrtle Warbler', 2),
#  ('Seaside Sparrow', 'Savannah Sparrow', 2),
#  ('Shiny Cowbird', 'Mourning Warbler', 2),
#  ('Slaty Backed Gull', 'Pomarine Jaeger', 2),
#  ('Song Sparrow', 'Brewer Sparrow', 2),
#  ('Song Sparrow', 'Harris Sparrow', 2),
#  ('Song Sparrow', 'Savannah Sparrow', 2),
#  ('Spotted Catbird', 'Painted Bunting', 2),
#  ('Swainson Warbler', 'Bewick Wren', 2),
#  ('Tennessee Warbler', 'Mourning Warbler', 2),
#  ('Tennessee Warbler', 'Nashville Warbler', 2),
#  ('Tennessee Warbler', 'Philadelphia Vireo', 2),
#  ('Tree Sparrow', 'Bewick Wren', 2),
#  ('Tree Sparrow', 'Clay Colored Sparrow', 2),
#  ('Tree Sparrow', 'House Sparrow', 2),
#  ('Tropical Kingbird', 'Great Crested Flycatcher', 2),
#  ('Vesper Sparrow', 'Grasshopper Sparrow', 2),
#  ('Vesper Sparrow', 'Lincoln Sparrow', 2),
#  ('Warbling Vireo', 'Red Eyed Vireo', 2),
#  ('Warbling Vireo', 'Swainson Warbler', 2),
#  ('Warbling Vireo', 'Tennessee Warbler', 2),
#  ('Western Gull', 'Glaucous Winged Gull', 2),
#  ('Western Wood Pewee', 'Warbling Vireo', 2),
#  ('White Eyed Vireo', 'Red Eyed Vireo', 2),
#  ('White Eyed Vireo', 'Yellow Throated Vireo', 2),
#  ('White Necked Raven', 'Fish Crow', 2),
#  ('White Necked Raven', 'Frigatebird', 2),
#  ('White Throated Sparrow', 'Brewer Sparrow', 2),
#  ('White Throated Sparrow', 'Song Sparrow', 2),
#  ('Wilson Warbler', 'Hooded Warbler', 2),
#  ('Winter Wren', 'Song Sparrow', 2),
#  ('Worm Eating Warbler', 'Great Crested Flycatcher', 2),
#  ('Yellow Bellied Flycatcher', 'Least Flycatcher', 2),
#  ('Yellow Billed Cuckoo', 'Mangrove Cuckoo', 2),
#  ('Yellow Breasted Chat', 'Common Yellowthroat', 2),
#  ('Yellow Throated Vireo', 'Nashville Warbler', 2),
#  ('Yellow Warbler', 'Blue Winged Warbler', 2)]

# %%
# using all the get_transforms defaults except a couple which we're changing
my_transforms = (get_transforms(
                   max_rotate=5.0, 
                   max_zoom=2.0) )

# %%
# Make a new data bunch, but size the images to 512 pixes square
data2 = (ImageList.from_df(images_df, data_path, cols='name') #Where to find the data?
        .split_from_df(col='is_valid') #How to split in train/valid?
        .label_from_df(cols='label') #How to label? -> depending on the folder of the filenames
        .transform(my_transforms, size=(512,512)) #Data transforms applied, images to 512
        .databunch(bs=12)) # We lower the batch size so we don't overwhelm the computer

# %%
# put this new data into the learner ...
learn.data = data2

# %%
# freeze what we've trained before
learn.freeze()

# %%
# train some more
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.359418</td>
#       <td>1.480600</td>
#       <td>0.397397</td>
#       <td>05:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.363633</td>
#       <td>1.330972</td>
#       <td>0.364031</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.766597</td>
#       <td>1.078548</td>
#       <td>0.299299</td>
#       <td>05:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.438091</td>
#       <td>0.935486</td>
#       <td>0.261261</td>
#       <td>05:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.302610</td>
#       <td>0.909756</td>
#       <td>0.255088</td>
#       <td>05:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.505136</td>
#       <td>1.029546</td>
#       <td>0.287955</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.697905</td>
#       <td>1.083849</td>
#       <td>0.293460</td>
#       <td>05:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.590000</td>
#       <td>0.981030</td>
#       <td>0.263430</td>
#       <td>05:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.193702</td>
#       <td>0.859448</td>
#       <td>0.234401</td>
#       <td>05:28</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.077374</td>
#       <td>0.837242</td>
#       <td>0.229229</td>
#       <td>05:28</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Saving your work
#
# At present, your Google Colaboratory Notebook disappears when you close it — along with all of your data and the values of the variables we set. That includes the model, which is called `learn`.
#
# ### Saving *notebooks* to Google Drive
#
# You may have seen this alert ...
#
# ![change runtime](https://qz-aistudio-public.s3.amazonaws.com/workshops/notebook_images/save_alert.png)
#
# ... or even thought to save your notebook to Google Drive using the menu bar.
#
# ![pick gpu](https://qz-aistudio-public.s3.amazonaws.com/workshops/notebook_images/save_dropdown.png)
#
# **_IMPORTANT NOTE: Saving your notebook this way does not save your data or your models ... it saves only the text of the notebook as you see it._**
#
# You are welcome to do this, but also note that your saved version won't include any future changes, improvements, or bug-fixes I make in the notebook. For that, be sure to start anew each time from Github.
#
# ### Saving *models* to Google Drive
#
# If you've got a really sweet predictor and want to save your model, you can!
#
# You need to connect your Google Colaboratory notebook to your Google Drive, where we'll make a folder called "ai-workshop." You can do that by running the following cell and following the prompts:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'ai-workshop/bird_models/'
save_path = Path(base_dir)
save_path.mkdir(parents=True, exist_ok=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# The next line will save everything we need for predictions to a file to your Google Drive in the `ai-workshops` folder.

# %% [markdown]
# ## Versions Saved
#
# **export_23pct_err.pkl**
# - 0.23 error_rate
# - ResNet34
# - 8 epochs @ size 224 w/ default transforms
# - 10 epochs @ size 512 w/ bike transforms
# - no unfreezing
# - split based on file
# - no LR finding
#
# **next**
# - ResNet50
# - 8 epochs @ size 224 w/default transforms = 0.31

# %%
base_dir = root_dir + 'ai-workshop/bird_models/'
save_path = Path(base_dir)
save_path.mkdir(parents=True, exist_ok=True)
learn.export(save_path/"export_23pct_err.pkl")

# %% [markdown]
# ### Using your model elsewhere (advanced)

# %% [markdown]
# Making _predictions_ – that is, guessing the class or contents of an image – is something for which you don't need a powerful computer. You don't need a GPU, or graphics processing unit. A regular computer's CPU (central processing unit) will do just fine.
#
# If you know how ([or take a moment to learn how](https://jupyter.readthedocs.io/en/latest/content-quickstart.html)) to run this notebook as a "jupyter notebook," you can run this code right off your own laptop. This can be especially useful if you have all your data on your computer and it's too much to upload to Google Colaboratory.
#
# Here's how to tell fast.ai to use the CPU instead of GPU.

# %%
defaults.device = torch.device('cpu')  # for the gpu it would be 'cuda'

# %% [markdown]
# To use your model, you'll need to load it into the code.
#
# Here's how to load it from your Google Drive:

# %%
# load the model from the 'export.pkl' file on your Google Drive
learn = load_learner(save_path)

# %% [markdown]
# Or you can download the `.pkl` file to your own computer and load it from there.

# %%
# load the model from your own computer
learn = load_learner('path/to/your/model/export.pkl')

# %%
# Then, load in an image and predict away!

img = open_image('path/to/an/image/file')

pred_class,pred_idx,outputs = learn.predict(img)

# %%
pred_class

# %% [markdown]
# To process data in real time – say, as tweets are tweeted or whenever a helicopter is flying – you can also host your code on a service like [Render](https://render.com). The guide for production deployment to Render is at https://course.fast.ai/deployment_render.html. Also check out [Render's fast.ai forum thread](https://forums.fast.ai/t/deployment-platform-render/33953) for questions and support.
